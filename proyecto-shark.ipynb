# %%
import pandas as pd

# Añadimos encoding='latin1' para que entienda los caracteres especiales
df = pd.read_csv("GSAF5(Sheet1-GSAF) (1).csv", encoding='latin1')

# Para ver si cargó bien
df.head()
# Out:
# C:\Users\naila\AppData\Local\Temp\ipykernel_23440\3378033241.py:4: DtypeWarning: Columns (0: Date, 1: Type, 2: Country, 3: State, 4: Location, 5: Activity, 6: Name, 7: Sex, 8: Age, 9: Injury, 10: Fatal Y/N, 11: Time, 12: Species , 13: Source, 14: pdf, 15: href formula, 16: href, 17: Case Number, 18: Case Number.1, 19: Unnamed: 21, 20: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("GSAF5(Sheet1-GSAF) (1).csv", encoding='latin1')
#               Date    Year        Type    Country             State  \
# 0            14/04  2026.0  UNprovoked   Maldives  Gaafu Alif Atoll
# 1        3rd April  2026.0  Unprovoked  Australia   South Australia
# 2       26th March  2026.0  Unprovoked    Bahamas     Andros Island
# 3       25th March  2026.0  Unprovoked  Australia   South Australia
# 4  22nd-23rd March  2026.0  Unprovoked  Australia               NSW
#
#                                       Location  Activity  \
# ...
